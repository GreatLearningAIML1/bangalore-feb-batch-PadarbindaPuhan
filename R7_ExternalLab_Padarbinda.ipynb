# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
x_train = x_train / 255.0

# %%
x_test = x_test / 255.0

# %%
x_train = x_train.reshape(x_train.shape[0],28,28,1)

# %%
x_test = x_test.reshape(x_test.shape[0],28,28,1)

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
model = tf.keras.models.Sequential()
#model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(200, activation='relu'))
model.add(tf.keras.layers.Dense(100, activation='relu'))
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
model.fit(x_train,y_train,          
          validation_data=(x_test,y_test),
          epochs=50)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.5214 - acc: 0.8135 - val_loss: 0.4053 - val_acc: 0.8525
# Epoch 2/50
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.3827 - acc: 0.8614 - val_loss: 0.3737 - val_acc: 0.8605
# Epoch 3/50
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.3465 - acc: 0.8743 - val_loss: 0.3709 - val_acc: 0.8608
# Epoch 4/50
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.3267 - acc: 0.8803 - val_loss: 0.3582 - val_acc: 0.8695
# Epoch 5/50
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.3077 - acc: 0.8870 - val_loss: 0.3455 - val_acc: 0.8738
# Epoch 6/50
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.2923 - acc: 0.8918 - val_loss: 0.3437 - val_acc: 0.8750
# Epoch 7/50
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.2826 - acc: 0.8946 - val_loss: 0.3511 - val_acc: 0.8732
# Epoch 8/50
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.2702 - acc: 0.8991 - val_loss: 0.3373 - val_acc: 0.8798
# Epoch 9/50
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.2628 - acc: 0.9017 - val_loss: 0.3291 - val_acc: 0.8849
# Epoch 10/50
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.2534 - acc: 0.9042 - val_loss: 0.3433 - val_acc: 0.8847
# Epoch 11/50
# 60000/60000 [==============================] - 7s 108us/sample - loss: 0.2448 - acc: 0.9065 - val_loss: 0.3527 - val_acc: 0.8804
# Epoch 12/50
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.2393 - acc: 0.9098 - val_loss: 0.3575 - val_acc: 0.8831
# Epoch 13/50
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.2343 - acc: 0.9125 - val_loss: 0.3410 - val_acc: 0.8860
# Epoch 14/50
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.2292 - acc: 0.9135 - val_loss: 0.3555 - val_acc: 0.8846
# Epoch 15/50
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.2204 - acc: 0.9163 - val_loss: 0.3427 - val_acc: 0.8867
# Epoch 16/50
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.2154 - acc: 0.9179 - val_loss: 0.3573 - val_acc: 0.8819
# Epoch 17/50
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.2085 - acc: 0.9196 - val_loss: 0.3335 - val_acc: 0.8868
# Epoch 18/50
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.2065 - acc: 0.9216 - val_loss: 0.3654 - val_acc: 0.8858
# Epoch 19/50
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.2022 - acc: 0.9221 - val_loss: 0.3681 - val_acc: 0.8901
# Epoch 20/50
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.1992 - acc: 0.9240 - val_loss: 0.3803 - val_acc: 0.8884
# Epoch 21/50
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.1935 - acc: 0.9248 - val_loss: 0.3583 - val_acc: 0.8895
# Epoch 22/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.1913 - acc: 0.9267 - val_loss: 0.3660 - val_acc: 0.8884
# Epoch 23/50
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.1878 - acc: 0.9277 - val_loss: 0.3592 - val_acc: 0.8910
# Epoch 24/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.1843 - acc: 0.9285 - val_loss: 0.3945 - val_acc: 0.8880
# Epoch 25/50
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.1810 - acc: 0.9301 - val_loss: 0.3919 - val_acc: 0.8886
# Epoch 26/50
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.1786 - acc: 0.9309 - val_loss: 0.3811 - val_acc: 0.8905
# Epoch 27/50
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.1749 - acc: 0.9327 - val_loss: 0.4206 - val_acc: 0.8843
# Epoch 28/50
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.1725 - acc: 0.9343 - val_loss: 0.4045 - val_acc: 0.8943
# Epoch 29/50
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.1706 - acc: 0.9342 - val_loss: 0.4062 - val_acc: 0.8921
# Epoch 30/50
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.1674 - acc: 0.9347 - val_loss: 0.4170 - val_acc: 0.8929
# Epoch 31/50
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.1678 - acc: 0.9350 - val_loss: 0.4193 - val_acc: 0.8844
# Epoch 32/50
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.1623 - acc: 0.9374 - val_loss: 0.4175 - val_acc: 0.8921
# Epoch 33/50
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.1629 - acc: 0.9375 - val_loss: 0.4295 - val_acc: 0.8891
# Epoch 34/50
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.1589 - acc: 0.9392 - val_loss: 0.4333 - val_acc: 0.8934
# Epoch 35/50
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.1545 - acc: 0.9397 - val_loss: 0.4361 - val_acc: 0.8933
# Epoch 36/50
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.1555 - acc: 0.9397 - val_loss: 0.4341 - val_acc: 0.8911
# Epoch 37/50
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.1511 - acc: 0.9414 - val_loss: 0.4740 - val_acc: 0.8841
# Epoch 38/50
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.1508 - acc: 0.9411 - val_loss: 0.4504 - val_acc: 0.8914
# Epoch 39/50
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.1487 - acc: 0.9413 - val_loss: 0.4674 - val_acc: 0.8914
# Epoch 40/50
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.1459 - acc: 0.9437 - val_loss: 0.4937 - val_acc: 0.8899
# Epoch 41/50
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.1444 - acc: 0.9434 - val_loss: 0.4837 - val_acc: 0.8884
# Epoch 42/50
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.1451 - acc: 0.9437 - val_loss: 0.4595 - val_acc: 0.8911
# Epoch 43/50
# 60000/60000 [==============================] - 7s 108us/sample - loss: 0.1404 - acc: 0.9452 - val_loss: 0.5061 - val_acc: 0.8916
# Epoch 44/50
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.1424 - acc: 0.9444 - val_loss: 0.4904 - val_acc: 0.8883
# Epoch 45/50
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.1368 - acc: 0.9461 - val_loss: 0.4868 - val_acc: 0.8943
# Epoch 46/50
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.1382 - acc: 0.9466 - val_loss: 0.5091 - val_acc: 0.8822
# Epoch 47/50
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.1351 - acc: 0.9486 - val_loss: 0.5270 - val_acc: 0.8928
# Epoch 48/50
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.1317 - acc: 0.9481 - val_loss: 0.5065 - val_acc: 0.8904
# Epoch 49/50
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.1304 - acc: 0.9482 - val_loss: 0.5225 - val_acc: 0.8816
# Epoch 50/50
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.1322 - acc: 0.9481 - val_loss: 0.5294 - val_acc: 0.8917

# %%
print("train score", model.evaluate(x_train,y_train))
# Out:
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.1100 - acc: 0.9559
# train score [0.11001914396584034, 0.9559]

# %%
print("test score", model.evaluate(x_test,y_test))
# Out:
# 10000/10000 [==============================] - 0s 46us/sample - loss: 0.5294 - acc: 0.8917
# test score [0.5293903447180986, 0.8917]

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_14 (Dense)             multiple                  157000
# _________________________________________________________________
# dense_15 (Dense)             multiple                  20100
# _________________________________________________________________
# dropout_6 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_16 (Dense)             multiple                  1010
# =================================================================
# Total params: 178,110
# Trainable params: 178,110
# Non-trainable params: 0
# _________________________________________________________________
